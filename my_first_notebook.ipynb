# %% [markdown]
# What is the difference between hardware and software? Give one example of each.

# %%
software : software is a set of instructions. Examples for sofware is Web browsers like whatsapp, google cheome ,etc.
Hardware : Hardware means the physical parts of a computer that we can touch or see.Exaples for hardware is keyboard,cpu,gpu,monitor ,etc.
